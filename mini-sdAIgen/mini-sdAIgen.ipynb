# %% [markdown]
# # Mini-sdAIgen
# A lightweight, focused downloader for ComfyUI workflows on Kaggle/Colab.
#
# ### Instructions
# 1. Run the **Setup** cell to install dependencies.
# 2. Run the **Widgets** cell to configure your API tokens and Model URLs.
# 3. Run the **Download** cell to start downloading.
# 4. Run the **Launch** cell to start ComfyUI.

# %%
# 1. Setup Environment
import sys
import os

# Ensure repo is in path
repo_path = os.path.abspath("mini-sdAIgen")
if repo_path not in sys.path:
    sys.path.append(repo_path)

# Run setup script
# !python mini-sdAIgen/setup.py
# Out:
# Detected Local/Other environment.
# Installing system dependencies...
# aria2c not found.
# Please install aria2c manually on Windows (e.g., 'winget install aria2' or 'choco install aria2').
# Installing Python dependencies...
# Requirement already satisfied: ipywidgets in f:\pythons\python311\lib\site-packages (8.1.5)
# Collecting gdown
#   Using cached gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\administrator\appdata\roaming\python\python311\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in f:\pythons\python311\lib\site-packages (from ipywidgets) (9.1.0)
# Requirement already satisfied: traitlets>=4.3.1 in f:\pythons\python311\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in f:\pythons\python311\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in f:\pythons\python311\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: beautifulsoup4 in f:\pythons\python311\lib\site-packages (from gdown) (4.9.3)
# Requirement already satisfied: filelock in f:\pythons\python311\lib\site-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in f:\pythons\python311\lib\site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in f:\pythons\python311\lib\site-packages (from gdown) (4.66.6)
# Requirement already satisfied: colorama in f:\pythons\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in f:\pythons\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in f:\pythons\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in f:\pythons\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in f:\pythons\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in f:\pythons\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in f:\pythons\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack_data in f:\pythons\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in f:\pythons\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in f:\pythons\python311\lib\site-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\pythons\python311\lib\site-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in f:\pythons\python311\lib\site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\pythons\python311\lib\site-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in f:\pythons\python311\lib\site-packages (from requests[socks]->gdown) (2024.8.30)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in f:\pythons\python311\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in f:\pythons\python311\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in f:\pythons\python311\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in f:\pythons\python311\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in f:\pythons\python311\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Installing collected packages: PySocks, gdown
# Successfully installed PySocks-1.7.1 gdown-5.2.0
# Setup complete! You can now run the widgets.
# DEPRECATION: Loading egg at f:\pythons\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 2. Configure Widgets
import launch
launch.show_widgets()
# Out:
# VBox(children=(HTML(value='<h2>Mini-sdAIgen Configuration</h2>'), Text(value='', description='HF Token:', plac…

# %%
# 3. Start Download
launch.run_download()
# Out:
# Parsing Empowerment text...
# Found 1 items to download.
# Starting batch download of 1 items...
# Executing: aria2c --console-log-level=error --summary-interval=10 -c -x16 -s16 -k1M -j5 --allow-overwrite=true -d "\root\ComfyUI\models\unet" "https://workers-playground-lucky-grass-a191.faturrachman6773.workers.dev/models/numz/SeedVR2_comfyUI/main/seedvr2_ema_7b_sharp_fp16.safetensors"
# Error downloading https://workers-playground-lucky-grass-a191.faturrachman6773.workers.dev/models/numz/SeedVR2_comfyUI/main/seedvr2_ema_7b_sharp_fp16.safetensors: Command 'aria2c --console-log-level=error --summary-interval=10 -c -x16 -s16 -k1M -j5 --allow-overwrite=true -d "\root\ComfyUI\models\unet" "https://workers-playground-lucky-grass-a191.faturrachman6773.workers.dev/models/numz/SeedVR2_comfyUI/main/seedvr2_ema_7b_sharp_fp16.safetensors"' returned non-zero exit status 1.
# Download process finished.

# %%
# 4. Launch ComfyUI (Placeholder)
# Adjust command as needed for your specific ComfyUI launch method
# !python /root/ComfyUI/main.py --listen --port 8188
